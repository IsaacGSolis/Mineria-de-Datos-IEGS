# %% [markdown]
# <a href="https://colab.research.google.com/github/IsaacGSolis/Mineria-de-Datos-IEGS/blob/main/FunAvanPandasPart1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df=pd.read_csv("part1_employees.csv")
df.head()
# Out:
#    emp_id   name  city   dept   level   hire_date  salary_mxn  perf_score  \
# 0     101    Ana  CDMX  Sales  Senior  2025-11-15       48000        0.90
# 1     102   Luis   GDL  Sales  Junior  2026-01-10       22000        0.82
# 2     103  Marta   MTY    Ops     Mid  2024-06-01       32000        0.75
# 3     104  Jorge  CDMX    Ops  Senior  2023-03-20       51000        0.88
# 4     105  Sofia   QRO     HR     Mid  2022-09-05       30000        0.93
#
#    projects  warnings  absences
# 0        12         1         2
# 1         5         0         0
# 2         8         1         1
# 3        10         0         0
# 4         6         0         0

# %% [markdown]
# Obtén todas las filas del depto "Eng" que además tengan perf_score >= 0.85, pero muestra solo las columnas: emp_id, name, city, perf_score, salary_mxn.

# %%
x=(df["perf_score"]>=0.85)&(df["dept"]=="Eng")
df.loc[x,["emp_id","name","dept","city","perf_score","salary_mxn"]]
# Out:
#     emp_id   name dept  city  perf_score  salary_mxn
# 6      107  Karla  Eng   MTY        0.95       40000
# 11     112  Ramon  Eng  CDMX        0.92       90000

# %% [markdown]
# Del DataFrame completo, obtén las filas 3 a 8 (incluyendo 3 y excluyendo 8), y solo las columnas 0, 1, 5 y 6 (por posición).

# %%
df.iloc[3:8]
# Out:
#    emp_id   name  city   dept   level   hire_date  salary_mxn  perf_score  \
# 3     104  Jorge  CDMX    Ops  Senior  2023-03-20       51000        0.88
# 4     105  Sofia   QRO     HR     Mid  2022-09-05       30000        0.93
# 5     106  Diego   GDL    Eng  Senior  2021-02-14       78000        0.70
# 6     107  Karla   MTY    Eng  Junior  2025-07-01       40000        0.95
# 7     108  Pedro  CDMX  Sales     Mid  2020-10-30       35000        0.60
#
#    projects  warnings  absences
# 3        10         0         0
# 4         6         0         0
# 5        14         2         1
# 6         7         0         0
# 7         9         3         2

# %% [markdown]
# Filtra empleados que estén en city CDMX o GDL, con warnings == 0 y absences <= 1. Muestra emp_id, name, city, warnings, absences.

# %%
result=df.query("(city == 'CDMX' or city == 'GDL') and warnings == 0 and absences <= 1")[["emp_id","name","city","warnings","absences"]]
result
# Out:
#     emp_id      name  city  warnings  absences
# 1      102      Luis   GDL         0         0
# 3      104     Jorge  CDMX         0         0
# 11     112     Ramon  CDMX         0         1
# 16     117  Fernanda  CDMX         0         0

# %% [markdown]
# Calcular salario promedio (salary_mxn)

# %%
df["salary_mxn"].mean()
# Out:
# np.float64(43200.0)

# %% [markdown]
# Calcular perf promedio (perf_score)

# %%
df["perf_score"].mean()
# Out:
# np.float64(0.8145)

# %% [markdown]
# Calcular total de warnings (warnings)

# %%
df["warnings"].sum()
# Out:
# np.int64(14)

# %% [markdown]
# Calcula:
# salario promedio (salary_mxn)
# perf promedio (perf_score)
# total de warnings (warnings)
# en una sola salida (por ejemplo usando agg).

# %%
df.agg({
    "salary_mxn": "mean",
    "perf_score": "mean",
    "warnings": "sum"
})
# Out:
# salary_mxn    43200.0000
# perf_score        0.8145
# warnings         14.0000
# dtype: float64

# %% [markdown]
# Por cada dept, calcula:
# número de empleados
# salario promedio
# perf promedio
# Ordena el resultado por salario promedio descendente.

# %%
dept=df.groupby('dept').agg(
    num_empleados=('emp_id', 'size'),
    salario_promedio=('salary_mxn', 'mean'),
    perf_promedio=('perf_score', 'mean')
)

dept_sorted = dept.sort_values(by='salario_promedio', ascending=False)
dept_sorted.head()
# Out:
#        num_empleados  salario_promedio  perf_promedio
# dept
# Eng                6      62833.333333          0.835
# Sales              6      35833.333333          0.780
# Ops                5      34400.000000          0.780
# HR                 3      33333.333333          0.900
